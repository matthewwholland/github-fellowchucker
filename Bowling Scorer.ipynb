# %%
import math

# %%
# Frame 1
a = input("Enter your scores separated by commas ""(without spaces)"" for frame 1. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr1 = [(item) for item in a.split(',')]
print("Frame 1:", fr1)

# %%
# Frame 2
b = input("Enter your scores separated by commas ""(without spaces)"" for frame 2. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr2 = [(item) for item in b.split(',')]
print("Frame 2:", fr2)

# %%
# Frame 3
c = input("Enter your scores separated by commas ""(without spaces)"" for frame 3. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr3 = [(item) for item in c.split(',')]
print("Frame 3:", fr3)

# %%
# Frame 4
d = input("Enter your scores separated by commas ""(without spaces)"" for frame 4. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr4 = [(item) for item in d.split(',')]
print("Frame 4:", fr4)

# %%
# Frame 5
e = input("Enter your scores separated by commas ""(without spaces)"" for frame 5. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr5 = [(item) for item in e.split(',')]
print("Frame 5:", fr5)

# %%
## Frame 6
f = input("Enter your scores separated by commas ""(without spaces)"" for frame 6. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr6 = [(item) for item in f.split(',')]
print("Frame 6:", fr6)

# %%
# Frame 7

g = input("Enter your scores separated by commas ""(without spaces)"" for frame 7. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr7 = [(item) for item in g.split(',')]
print("Frame 7:", fr7)

# %%
# Frame 8

h = input("Enter your scores separated by commas ""(without spaces)"" for frame 8. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr8 = [(item) for item in h.split(',')]
print("Frame 8:", fr8)

# %%
# Frame 9

i = input("Enter your scores separated by commas ""(without spaces)"" for frame 9. Enter ""strike"" for a strike and ""spare"" for a spare.")
fr9 = [(item) for item in i.split(',')]
print("Frame 9:", fr9)

# %%
# Frame 10

j = input("Enter your scores separated by commas ""(without spaces)"" for frame 10. Enter ""strike"" for a strike and ""spare"" for a spare. Enter three scores if necessary." )
fr10 = [(item) for item in j.split(',')]
print("Frame 10:", fr10)

# %%
# frames is a list of lists
# scores is a list
frames = [fr1, fr2, fr3, fr4, fr5, fr6, fr7, fr8, fr9, fr10]
scores = fr1 + fr2 + fr3 + fr4 + fr5 + fr6 + fr7 + fr8 + fr9 + fr10
print(frames)
print(scores)

# %%
# No strikes or spares
if ('spare' not in scores) and ('strike' not in scores):
    score = [int(item) for item in scores]
    score1 = sum(score)
    print("Your score is", score1)
    
    
# No strikes or spares (1-9), strikes in tenth frame
if (any('spare' in sublist for sublist in frames) == False) and (any('strike' in sublist for sublist in frames) == False) and (['strike'] in frames[9]) and (['spare'] not in frames[9]) and ('strike' not in scores[0:8][0:8]):
    score = [s.replace('strike', '10') for s in scores]
    score1 = [int(item) for item in score]
    score2 = sum(score1)
    print("Your score is", score2)
    
    
# No strikes or spares (1-9), strikes and spares in tenth frame
if (any('spare' in sublist for sublist in frames) == False) and (any('strike' in sublist for sublist in frames) == False) and ('strike' in frames[9]) and ('spare' in frames[9]):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]
    for i in range(len(score2)):
        if score2[i] == 10:
            score2[i] = 10 - score2[i-1]
    score3 = sum(score2)
    print("Your score is", math.floor(score3))
    
    
# Spares, but not in frame 10, no strikes
if ('spare' in scores) and ('strike' not in scores) and ('spare' not in frames[9]):
    score = [s.replace('spare', '10') for s in scores]
    score1 = [int(item) for item in score]
    for i in range(len(score1)):
        if score1[i] == 10:
            score1[i] = -score1 [i-1] + score1[i] + score1[i + 1]

    score2 = sum(score1)
    print("Your score is", score2)

    
# Strikes, but not in frame 10, no spares
if ('spare' not in scores) and ('strike' in scores) and ('strike' not in frames[9]):
    score = [s.replace('strike', '10') for s in scores]
    score1 = [int(item) for item in score]

    for i in range(len(score1)):
        if score1[i] == 10:
            score1[i] = score1[i] + score1[i + 1] + score1[i + 2]
            score2 = sum(score1)
    print("Your score is", score2)
    
    
# Strikes, but no spares
if ('spare' not in scores) and ('strike' in scores) and ('strike' in frames[9]):
    score = [s.replace('strike', '10') for s in scores]
    
    score1 = [int(item) for item in score]
    
    for i in range(len(score1)-3):
        if score1[i] == 10:
            score1[i] = score1[i] + score1[i + 1] + score1[i + 2]
    print("Your score is", sum(score1))
    
    
# Spares and strikes, but not in frame 10
if ('spare' in scores) and ('strike' in scores) and ('strike' not in frames[9]) and ('spare' not in frames[9]):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]

    score3 = score2.copy()
    
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3)):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])

    strikes_correction = []
    for i in range (len(score2)):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
    
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares)
    print("Your score is", math.floor(total))
    
    
# Spares in all frames, no strikes
if ('spare' in scores) and ('strike' not in scores) and ('spare' in frames[9]):
    score = [s.replace('spare', '10') for s in scores]
    score1 = [int(item) for item in score]

    for i in range(len(score1)-1):
        if score1[i] == 10:
            score1[i] = -score1 [i-1] + score1[i] + score1[i + 1]

    score2 = sum(score1) - score1[-1]
    print("Your score is", score2)
    
    
# Spares and strikes (no strikes in frame 10)
if ('spare' in scores) and ('strike' in scores) and ('spare' in frames[9]) and ('strike' not in frames[9]):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]

    score3 = score2.copy()
    
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3)):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])

    strikes_correction = []
    for i in range (len(score2)):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
    
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares) - score2[-1]
    print("Your score is", math.floor(total))
    
    
# Spares and strikes (frame 10 strike first throw, then two integers)
if ('spare' in scores) and ('strike' in scores) and (frames[9][0] == 'strike') and (frames[9][1] != 'strike') and (frames[9][2] != 'strike'):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]

    score3 = score2.copy()
    
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 1):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2) - 1):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
    
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
 
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares) - score2[-1] - score2[-2]
    print("Your score is", math.floor(total))
    
    
# Spares and strikes (frame 10 all strikes)
try:
    if ('spare' in scores) and ('strike' in scores) and (frames[9] == ['strike','strike','strike']):
        score = [s.replace('strike', '10.01') for s in scores]
        score1 = [s.replace('spare', '10') for s in score]
        score2 = [float(item) for item in score1]
        score3 = score2.copy()
except IndexError:
    pass
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 3):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
    
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
    
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])

    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares)
    print("Your score is", math.floor(total))
except IndexError:
    pass
    
    
# Spares and strikes (frame 10 two strikes, then integer)
if ('spare' in scores) and ('strike' in scores) and (frames[9][0] == 'strike') and (frames[9][1] == 'strike') and (len(frames[9][2]) == 1):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]

    score3 = score2.copy()
    
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 3):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2) - 1):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
            
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
 
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares)
    print("Your score is", math.floor(total))
    
    
# Spares and strikes (frame 10 two strikes, then integer)
if ('spare' in scores) and ('strike' in scores) and (frames[9] == ['strike','strike','strike']):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]
    score3 = score2.copy()

    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 3):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
    
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
    
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])

    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares)
    print("Your score is", math.floor(total))
    
    
# Spares and strikes (frame 10 integer, spare, strike)
try:
    if (len(frames[9][0]) == 1) and (frames[9][1] == 'spare') and (frames[9][2] == 'strike') and ('spare' in scores) and ('strike' in scores):
        score = [s.replace('strike', '10.01') for s in scores]
        score1 = [s.replace('spare', '10') for s in score]
        score2 = [float(item) for item in score1]
        score3 = score2.copy()
except IndexError:
    pass
    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 1):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
    
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
except IndexError:
    pass
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares) - score2[-1]
    print("Your score is", math.floor(total))
except IndexError:
    pass


# Spares and strikes (frame 10 integer, spare, strike)
if (len(frames[9][0]) == 1) and (frames[9][1] == 'spare') and (frames[9][2] == 'strike'):
    score = [s.replace('strike', '10.01') for s in scores]
    score1 = [s.replace('spare', '10') for s in score]
    score2 = [float(item) for item in score1]
    score3 = score2.copy()

    for i in range(len(score3)):
        if score3[i] == 10.00:
            score3[i] = 10 - score3[i-1]
    
    strikes = []
    for i in range (len(score3) - 1):
        if score3[i] == 10.01:
            strikes.append((score3[i + 1] + score3[i + 2]))
            
    spares = []
    for i in range(len(score2)):
        if score2[i] == 10.00:
            spares.append(score2[i+1])
    
    strikes_correction = []
    for i in range (len(score2) - 1):
        if score2[i] == 10.00:
            strikes_correction.append(-score2[i-1])
            
    total = sum(score2) + sum(strikes) + sum(strikes_correction) + sum(spares) - score2[-1]
    print("Your score is", math.floor(total))

# %% [markdown]
# ####
